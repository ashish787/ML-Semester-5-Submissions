# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('../input/machine-learning-regression-and-regularization/train.csv')
test = pd.read_csv('../input/machine-learning-regression-and-regularization/test.csv')

# %%
x_test = test[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
test_total = x_test.sum(axis=1).values

test['Global_Sales'] = test_total

# %%
test[['id', 'Global_Sales']].to_csv('submission.csv', index=False)
